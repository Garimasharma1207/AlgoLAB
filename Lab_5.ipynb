# %% [markdown]
# # 2. Divide and Conquer (Sorting)

# %% [markdown]
# - **Created by Dr. Ajay

# %% [markdown]
# Write a python program to perform **selection sort**.
# - ** -Algorithm
# * Step 1: Read the number of elements for the list from the user.
# * Step 2: Using for loop insert the elements in the list.
# * Step 3: Initialize the minimum element as min=numbers[i].
# * Step 4: Using the swap method the elements are sorted accordingly.
# * Step 5: Print the sorted list.

# %%
#write code for above cell and compute the running time and also plot graph.
import time
import matplotlib.pyplot as plt
def selection_sort(arr):
  n=len(arr)
  for i in range(n):
    min_indx=i
    for j in range(i+1,n):
      if arr[j]<arr[min_indx]:
        min_indx=j
    arr[i],arr[min_indx]=arr[min_indx],arr[i]
  return arr
n=int(input("Enter number of elements:"))
numbers=[]
for i in range(n):
  num=int(input(f"Enter elements {i+1}: "))
  numbers.append(num)
sorted_list=selection_sort(numbers)
print("The sorted list is:",sorted_list)
n_values=list(range(10,101,10))
times=[]
for size in n_values:
  values=list(range(size,0,-1))
  start=time.time()
  selection_sort(values)
  end=time.time()
  times.append((end-start)*1000)
print("Running time in ms for following values are: ",times,"ms")
plt.figure()
plt.plot(n_values,times)
plt.xlabel("Input values")
plt.ylabel("Time")
plt.title("Selection Sort graph")
plt.show()
# Out:
# Enter number of elements:5
# Enter elements 1: 34
# Enter elements 2: 23
# Enter elements 3: 32
# Enter elements 4: 56
# Enter elements 5: 99
# The sorted list is: [23, 32, 34, 56, 99]
# Running time in ms for following values are:  [0.0059604644775390625, 0.009059906005859375, 0.016927719116210938, 0.03838539123535156, 0.044345855712890625, 0.05793571472167969, 0.07939338684082031, 0.09965896606445312, 0.1392364501953125, 0.16832351684570312] ms

# %% [markdown]
# In computer science, **merge sort** (also commonly spelled mergesort) is an efficient, general-purpose, comparison-based sorting algorithm. Most implementations produce a stable sort, which means that the order of equal elements is the same in the input and output. Merge sort is a divide and conquer algorithm that was invented by John von Neumann in 1945.
# Write a Python program to sort the elements using **merge sort** and plot a graph to the time taken versus n
# - Algorithm(Merge Sort is a divide and conquer algorithm. It divides	input array in two halve.s, calls itself for the two halves and then merges two sorted halves.)
# 1.	Divide the unsorted array into n partitions, each	partition contains 1 element.
# 2.	Repeatedly merge partitioned units to produce	new sublists until there is only l sublist remaining. This will be the sorted	.
# 3.	Compare the first element of the sublist with the first element of the sublist to its right.
# 4.	Merge the two sublists by	paring each element of the sublist and placing the smaller element into the	new sublist.
# 5.	Repeat step 3 and 4 untill	all sublists are merged into a single sorted sublist.

# %%
#write code for above cell and compute the running time and also plot graph.
import time
import matplotlib.pyplot as plt
def merge_sort(arr):
  if len(arr)>1:
    mid= len(arr)//2
    left=arr[:mid]
    right=arr[mid:]
    merge_sort(left)
    merge_sort(right)
    i=j=k=0
    while i < len(left) and j < len(right):
          if left[i] < right[j]:
                arr[k] = left[i]
                i += 1
          else:
                arr[k] = right[j]
                j += 1
          k += 1
    while i < len(left):
            arr[k] = left[i]
            i += 1
            k += 1

    while j < len(right):
          arr[k] = right[j]
          j += 1
          k += 1

    return arr
n=int(input("Enter number of elements:"))
numbers=[]
for i in range(n):
  num=int(input(f"Enter elements {i+1}: "))
  numbers.append(num)
merged_list=merge_sort(numbers)
print("The sorted list is:",merged_list)
n_values=list(range(10,101,10))
times=[]
for size in n_values:
  values=list(range(size,0,-1))
  start=time.time()
  merge_sort(values)
  end=time.time()
  times.append((end-start)*1000)
print("Running time in ms for following values are: ",times,"ms")
plt.figure()
plt.plot(n_values,times)
plt.xlabel("Input values")
plt.ylabel("Time")
plt.title("Merge Sort graph")
plt.show()
# Out:
# Enter number of elements:5
# Enter elements 1: 45
# Enter elements 2: 54
# Enter elements 3: 34
# Enter elements 4: 32
# Enter elements 5: 12
# The sorted list is: [12, 32, 34, 45, 54]
# Running time in ms for following values are:  [0.010013580322265625, 0.0152587890625, 0.02288818359375, 0.031948089599609375, 0.03790855407714844, 0.05173683166503906, 0.055789947509765625, 0.07772445678710938, 0.07414817810058594, 0.13446807861328125] ms

# %% [markdown]
# **Quicksort** (sometimes called partition-exchange sort) is an efficient sorting algorithm. Developed by British computer scientist Tony Hoare in 1959 and published in 1961, it is still a commonly used algorithm for sorting.
#
# Quicksort is a divide-and-conquer algorithm. It works by selecting a 'pivot' element from the array and partitioning the other elements into two sub-arrays, according to whether they are less than or greater than the pivot. The sub-arrays are then sorted recursively. This can be done in-place, requiring small additional amounts of memory to perform the sorting.
# Write a Python program to sort the elements using quick sort and plot a graph to the time taken versus n.
# - Algorithm
# 1.	Select a pivot element from the array.
# 2.	Partition the array into two sub-arrays. The elements in the first sub-array are less than the pivot element, while the elements in the second sub-array are greater than the pivot element.
# 3.	Recursively sort the sub-arrays created in Step 2.
# 4.	Join the sub-arrays and the pivot element together to	the sorted array.

# %%
#write code for above cell and compute the running time and also plot graph.
import time
import matplotlib.pyplot as plt
def quicksort(arr):
  if len(arr) <= 1:
        return arr
  else:
        pivot = arr[len(arr) // 2]
        left = [x for x in arr if x < pivot]
        middle = [x for x in arr if x == pivot]
        right = [x for x in arr if x > pivot]
        return quicksort(left) + middle + quicksort(right)
n=int(input("Enter number of elements:"))
numbers=[]
for i in range(n):
  num=int(input(f"Enter elements {i+1}: "))
  numbers.append(num)
sorted_list=quicksort(numbers)
print("The sorted list is:",sorted_list)
n_values=list(range(10,101,10))
times=[]
for size in n_values:
  values=list(range(size,0,-1))
  start=time.time()
  quicksort(values)
  end=time.time()
  times.append((end-start)*1000)
print("Running time in ms for following values are: ",times,"ms")
plt.figure()
plt.plot(n_values,times)
plt.xlabel("Input values")
plt.ylabel("Time")
plt.title("Quick Sort graph")
plt.show()
# Out:
# Enter number of elements:5
# Enter elements 1: 45
# Enter elements 2: 67
# Enter elements 3: 89
# Enter elements 4: 99
# Enter elements 5: 34
# The sorted list is: [34, 45, 67, 89, 99]
# Running time in ms for following values are:  [0.010728836059570312, 0.014543533325195312, 0.020742416381835938, 0.02956390380859375, 0.03886222839355469, 0.04363059997558594, 0.05078315734863281, 0.05745887756347656, 0.16164779663085938, 0.07605552673339844] ms

# %% [markdown]
# ### Experiment: compare sorting algorithms

# %%
# Experiment variables
n_list = [1000, 2000, 5000, 10000, 20000, 50000, 100000, 200000]
n_max = n_list[len(n_list) -1]

# %%
import random
from datetime import datetime

# Seed the random generator using current milliseconds
ms = datetime.now().microsecond // 1000
random.seed(ms)

# Generate n_max random integers between 0 and 999
numbers = [random.randint(0, 999) for _ in range(n_max)]

# %%
import copy
import timeit

a_time = []
b_time = []
c_time = []

for l in n_list:
    # Create fresh copies of the first l elements
    a = copy.deepcopy(numbers[:l])
    b = copy.deepcopy(numbers[:l])
    c = copy.deepcopy(numbers[:l])

    # Quick Sort timing
    start_time = timeit.default_timer()
    quick_sort(a)   # assuming you defined quick_sort()
    a_time.append((timeit.default_timer() - start_time) * 1000)

    # Merge Sort timing
    start_time = timeit.default_timer()
    merge_sort(b)   # assuming you defined merge_sort()
    b_time.append((timeit.default_timer() - start_time) * 1000)

    # Selection Sort timing (or built-in sort)
    start_time = timeit.default_timer()
    # If you wrote your own selection_sort function:
    # selection_sort(c)
    # Otherwise, use Python’s built-in sort:
    c.sort()
    c_time.append((timeit.default_timer() - start_time) * 1000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3232553447.py in <cell line: 0>()
#      14     # Quick Sort timing
#      15     start_time = timeit.default_timer()
# ---> 16     quick_sort(a)   # assuming you defined quick_sort()
#      17     a_time.append((timeit.default_timer() - start_time) * 1000)
#      18
#
# NameError: name 'quick_sort' is not defined

# %%
# Plotting results
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10, 5))
plt.plot(a_time, linewidth = 1, marker="o")
plt.plot(b_time, linewidth = 1, marker="o")
plt.plot(c_time, linewidth = 1, marker="o")
plt.xticks(np.arange(len(n_list)), n_list)
plt.title("Compare Sorting Algorithms", fontsize = 14)
plt.ylabel('Time (ms)')
plt.xlabel('n')
plt.legend(("Quicksort", "Mergesort", "Selection sort"), loc = "best")
plt.show()
